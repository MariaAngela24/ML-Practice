# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
lot(arange(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-35f2ffb0e50f> in <module>()
# ----> 1 lot(arange(5))
#
# NameError: name 'lot' is not defined

# %%
plot(arange(5))

# %%
df = pd.read_csv("/Users/mariamendiburo/src/practice/train_u6lujuX_CVtuZ9i.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8e10726f1554> in <module>()
# ----> 1 df = pd.read_csv("/Users/mariamendiburo/src/practice/train_u6lujuX_CVtuZ9i.csv")
#
# NameError: name 'pd' is not defined

# %%
read_csv("/Users/mariamendiburo/src/practice/train_u6lujuX_CVtuZ9i.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dcd7b5c1444c> in <module>()
# ----> 1 read_csv("/Users/mariamendiburo/src/practice/train_u6lujuX_CVtuZ9i.csv")
#
# NameError: name 'read_csv' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
pd.read_csv("/Users/mariamendiburo/src/practice/train_u6lujuX_CVtuZ9i.csv")
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6fae94b3c442> in <module>()
# ----> 1 df.head(10)
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv("/Users/mariamendiburo/src/practice/train_u6lujuX_CVtuZ9i.csv")

# %%
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
df['ApplicantIncome'].hist(bins=50)

# %%
df.boxplot(column='ApplicantIncome')

# %%
df.boxplot(column='ApplicantIncome', by = 'Education')

# %%
df['LoanAmount'].hist(bins=50)

# %%
df.boxplot(column='LoanAmount')

# %%
temp1 = df['Credit_History'].value_counts(ascending=True)
temp2 = df.pivot_table(values='Loan_Status',index=['Credit_History'],aggfunc=lambda x: x.map({'Y':1,'N':0}).mean())
print 'Frequency Table for Credit History:' 
print temp1

print '\nProbility of getting loan for each Credit History class:' 
print temp2
# Out:
# Frequency Table for Credit History:
# 0.0     89
# 1.0    475
# Name: Credit_History, dtype: int64
#
# Probility of getting loan for each Credit History class:
# Credit_History
# 0.0    0.078652
# 1.0    0.795789
# Name: Loan_Status, dtype: float64
